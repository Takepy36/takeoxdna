# %%
import numpy as np
import pyvista as pv
import os
import run_output_bonds_func as robf
import get_coordinate as gc
import importlib
import matplotlib.pyplot as plt
importlib.reload(robf)
importlib.reload(gc)
# Out:
# <module 'get_coordinate' from '/Users/takepy/kakenhievolvedna/oxdna_run/get_coordinate.py'>

# %%
def make_position_data_ndarray(connection_data):
    position_data = gc.get_coordinate_data(connection_data)
    return position_data.values

# %%
def plot_coordinate_vista(connection_data, target, output_dir = "output_oxDNA"):
    point_cloud = make_position_data_ndarray(connection_data)
    #print(point_cloud)
    pdata = pv.PolyData(point_cloud)
    #display(pdata)#N pointsの値, int
    n_points = pdata.n_points
    #pdata['orig_sphere'] = np.arange(n_points)
    sphere = pv.Sphere(radius=0.2, phi_resolution=10, theta_resolution=10)
    #display(sphere)
    # create many spheres from the point cloud
    pc = pdata.glyph(scale=False, geom=sphere)
    #display(pc)
    pc.plot(cmap='Reds')
    
    plt.savefig(os.path.join(output_dir, "{}.png".format(target)))

# %%
def main():
    target = "e0"
    connection_data = robf.create_connection_data(target, output_dir = "output_oxDNA")
    plot_coordinate_vista(connection_data, target)

# %%
if __name__ == "__main__":
    main()
# Out:
#     id1  id2        HB  strand nucleotide  position_rx  position_ry  \
# 0     0    1  0.000000       1          T  -227.626991    70.706160
# 1     0   20  0.000000       1          T  -227.626991    70.706160
# 2     0   22 -0.000000       1          T  -227.626991    70.706160
# 3     1    2  0.000000       1          T  -227.306824    71.054906
# 4     1   19  0.000000       1          T  -227.306824    71.054906
# 5     1   21 -0.000000       1          T  -227.306824    71.054906
# 6     2    3  0.000000       1          A  -227.152888    71.566034
# 7     2   18  0.000000       1          A  -227.152888    71.566034
# 8     2   19 -0.626961       1          A  -227.152888    71.566034
# 9     2   20  0.000000       1          A  -227.152888    71.566034
# 10    3    4  0.000000       1          T  -227.348633    72.056276
# 11    3   17 -0.000000       1          T  -227.348633    72.056276
# 12    3   19  0.000000       1          T  -227.348633    72.056276
# 13    4    5  0.000000       1          T  -227.618164    72.552116
# 14    4   16 -0.000000       1          T  -227.618164    72.552116
# 15    4   17 -0.683989       1          T  -227.618164    72.552116
# 16    4   18  0.000000       1          T  -227.618164    72.552116
# 17    5    6  0.000000       1          C  -227.952099    72.931056
# 18    5   15  0.000000       1          C  -227.952099    72.931056
# 19    5   17  0.000000       1          C  -227.952099    72.931056
# 20    6    7  0.000000       1          T  -227.974058    73.506158
# 21    6   14  0.000000       1          T  -227.974058    73.506158
# 22    6   15 -0.422575       1          T  -227.974058    73.506158
# 23    6   16  0.000000       1          T  -227.974058    73.506158
# 24    7    8  0.000000       1          C  -228.059472    73.874731
# 25    7   13  0.000000       1          C  -228.059472    73.874731
# 26    7   15  0.000000       1          C  -228.059472    73.874731
# 27    8    9  0.000000       1          T  -227.936270    74.240156
# 28    8   12  0.000000       1          T  -227.936270    74.240156
# 29    8   14 -0.000000       1          T  -227.936270    74.240156
# 30    9   10  0.000000       1          T  -227.709984    74.730054
# 31    9   11  0.000000       1          T  -227.709984    74.730054
# 32    9   12 -0.219726       1          T  -227.709984    74.730054
# 33    9   13 -0.000000       1          T  -227.709984    74.730054
# 34   10   11  0.000000       1          G  -227.519515    75.183897
# 35   11   12  0.000000       1          C  -227.486054    74.860131
# 36   12   13  0.000000       1          T  -227.234008    74.476688
# 37   13   14  0.000000       1          A  -226.969966    74.008217
# 38   14   15  0.000000       1          A  -226.899627    73.642592
# 39   15   16  0.000000       1          T  -227.042655    73.230978
# 40   16   17  0.000000       1          A  -227.254733    72.846946
# 41   17   18  0.000000       1          A  -227.620628    72.450434
# 42   18   19  0.000000       1          G  -228.024335    72.024142
# 43   19   20  0.000000       1          A  -228.318194    71.686591
# 44   20   21  0.000000       1          G  -228.473262    71.173917
# 45   21   22  0.000000       1          A  -228.268722    70.854661
# 46   22   23  0.000000       1          A  -228.101115    70.385714
# 47   23   24  0.000000       1          C  -227.728476    70.043313
# 48   24   25  0.000000       1          G  -227.593136    69.604352
#
#     position_rz id2_strand
# 0     19.573057          1
# 1     19.573057          1
# 2     19.573057          1
# 3     19.266832          1
# 4     19.266832          1
# 5     19.266832          1
# 6     18.970770          1
# 7     18.970770          1
# 8     18.970770          1
# 9     18.970770          1
# 10    18.743501          1
# 11    18.743501          1
# 12    18.743501          1
# 13    18.612688          1
# 14    18.612688          1
# 15    18.612688          1
# 16    18.612688          1
# 17    18.758104          1
# 18    18.758104          1
# 19    18.758104          1
# 20    18.889259          1
# 21    18.889259          1
# 22    18.889259          1
# 23    18.889259          1
# 24    19.210856          1
# 25    19.210856          1
# 26    19.210856          1
# 27    19.564273          1
# 28    19.564273          1
# 29    19.564273          1
# 30    19.804178          1
# 31    19.804178          1
# 32    19.804178          1
# 33    19.804178          1
# 34    19.303022          1
# 35    18.846590          1
# 36    18.691399          1
# 37    18.856612          1
# 38    19.175419          1
# 39    19.512338          1
# 40    19.679069          1
# 41    19.785496          1
# 42    19.702798          1
# 43    19.345734          1
# 44    18.979819          1
# 45    18.613739          1
# 46    18.581376          1
# 47    18.680638          1
# 48    18.797700          1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-972361fa1b80> in <module>
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# <ipython-input-6-a75823a39dd6> in main()
#       2     target = "e0"
#       3     connection_data = robf.create_connection_data(target, output_dir = "output_oxDNA")
# ----> 4     plot_coordinate_vista(connection_data, target)
#
# <ipython-input-3-d5d7ca813d3c> in plot_coordinate_vista(connection_data, target, output_dir)
#       2     point_cloud = make_position_data_ndarray(connection_data)
#       3     #print(point_cloud)
# ----> 4     pdata = pv.PolyData(point_cloud)
#       5     #display(pdata)#N pointsの値, int
#       6     n_points = pdata.n_points
#
# /opt/anaconda3/lib/python3.7/site-packages/pyvista/core/pointset.py in __init__(self, var_inp, faces, n_faces, lines, n_lines, deep, force_ext)
#     263         # First parameter is points
#     264         if isinstance(var_inp, (np.ndarray, list, _vtk.vtkDataArray)):
# --> 265             self.SetPoints(pyvista.vtk_points(var_inp, deep=deep))
#     266         else:
#     267             msg = f"""
#
# /opt/anaconda3/lib/python3.7/site-packages/pyvista/utilities/helpers.py in vtk_points(points, deep)
#     473     # verify shape
#     474     if points.shape[1] != 3:
# --> 475         raise ValueError('Points array must contain three values per point. '
#     476                          f'Shape is {points.shape} and should be (X, 3)')
#     477
#
# ValueError: Points array must contain three values per point. Shape is (49, 4) and should be (X, 3)
